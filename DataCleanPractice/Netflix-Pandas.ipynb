# %%
import pandas as pd

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df.head()
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Transpose
df.T
# Out:
#                                                            0     \
# show_id                                                      s1
# type                                                      Movie
# title                                      Dick Johnson Is Dead
# director                                        Kirsten Johnson
# cast                                                        NaN
# country                                           United States
# date_added                                   September 25, 2021
# release_year                                               2020
# rating                                                    PG-13
# duration                                                 90 min
# listed_in                                         Documentaries
# description   As her father nears the end of his life, filmm...
#
#                                                            1     \
# show_id                                                      s2
# ...

# %%
df.sort_values(by='title')
# Out:
#      show_id     type                          title  \
# 2036   s2037    Movie                         #Alive
# 2304   s2305    Movie  #AnneFrank - Parallel Stories
# 2481   s2482    Movie              #FriendButMarried
# 2324   s2325    Movie            #FriendButMarried 2
# 5973   s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 6177   s6178  TV Show                       忍者ハットリくん
# 4914   s4915  TV Show                           海的儿子
# 7101   s7102  TV Show                           마녀사냥
# 5022   s5023    Movie                        반드시 잡는다
# 7108   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# ...                           ...
# 6177                          NaN
# 4914                          NaN
# ...

# %%
#copy dataframe
df2 = df.copy()

# %%
df['type']
#OR df.type
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
#drop rows with any null values
df = df.dropna()

#replace rows with nulls with a value
#df = df.fillna(value='0')

# %%
#changing datatype
df['release_year'] = df['release_year'].astype('str')
df['release_year'] = df['release_year'].astype('int')

# %%
#brief stats on data
df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
#put number into variable
mean_df = df.release_year.mean()
mean_df
# Out:
# 2012.7421230307577

# %%
#add new column, row values are 5
df['new_column']=5

# %%
#drop a column, axis=1 looks at the columns instead of rows (0)
df = df.drop('new_column', axis=1)

# %%
#df.release_year + df.new_column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df.release_year + df.new_column
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'new_column'

# %%
#new column using existing column data
df['minus_100']=df.release_year - 100

# %%
df.loc[1:5]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, minus_100]
# Index: []

# %%
df.loc[:,['release_year','rating']]
# Out:
#       release_year rating
# 7             1993  TV-MA
# 8             2021  TV-14
# 9             2021  PG-13
# 12            2021  TV-MA
# 24            1998  TV-14
# ...            ...    ...
# 8801          2015  TV-MA
# 8802          2007      R
# 8804          2009      R
# 8805          2006     PG
# 8806          2015  TV-14
#
# [5332 rows x 2 columns]

# %%
df.loc[df['release_year']>2000]
# Out:
#      show_id     type                          title             director  \
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 27       s28    Movie                      Grown Ups         Dennis Dugan
# 28       s29    Movie                     Dark Skies        Scott Stewart
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.iloc[0,1]
# Out:
# 'Movie'

# %%
df.iloc[[0,1],:]
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  minus_100
# ...

# %%
df = df[df['rating']=='R']
df
# Out:
#      show_id   type                        title  \
# 46       s47  Movie                   Safe House
# 48       s49  Movie                 Training Day
# 81       s82  Movie                         Kate
# 122     s123  Movie                   In the Cut
# 131     s132  Movie  Blade Runner: The Final Cut
# ...      ...    ...                          ...
# 8765   s8766  Movie                           XX
# 8768   s8769  Movie            Y Tu Mamá También
# 8791   s8792  Movie                  Young Adult
# 8802   s8803  Movie                       Zodiac
# 8804   s8805  Movie                   Zombieland
#
#                                                director  \
# 46                                      Daniel Espinosa
# 48                                        Antoine Fuqua
# 81                                Cedric Nicolas-Troyan
# 122                                        Jane Campion
# 131                                        Ridley Scott
# ...

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#    index show_id   type                        title               director  \
# 0     46     s47  Movie                   Safe House        Daniel Espinosa
# 1     48     s49  Movie                 Training Day          Antoine Fuqua
# 2     81     s82  Movie                         Kate  Cedric Nicolas-Troyan
# 3    122    s123  Movie                   In the Cut           Jane Campion
# 4    131    s132  Movie  Blade Runner: The Final Cut           Ridley Scott
#
#                                                 cast  \
# 0  Denzel Washington, Ryan Reynolds, Vera Farmiga...
# 1  Denzel Washington, Ethan Hawke, Scott Glenn, T...
# 2  Mary Elizabeth Winstead, Jun Kunimura, Woody H...
# 3  Meg Ryan, Mark Ruffalo, Jennifer Jason Leigh, ...
# 4  Harrison Ford, Rutger Hauer, Sean Young, Edwar...
#
#                                             country          date_added  \
# 0                South Africa, United States, Japan  September 16, 2021
# ...

# %%
df = df.drop(['index'],axis=1)
df

# %%
for x in range(len(df.show_id)):
    if df['show_id'][x]=='s132':
        print(df['show_id'][x])
    else:
        print('not right')
# Out:
# not right
# not right
# not right
# not right
# s132
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# not right
# ...

# %%
#random sample of 100 rows from df 
df2 = df.sample(n=100)

# %%
#add them together
df3 = pd.concat([df,df2])

# %%
df3.shape
# Out:
# (878, 13)

# %%
#add into onto the end of existing df than creating a new one
df.append(df2)
# Out:
# /var/folders/31/j3sqrs8169bfz_hbqzpdft6m0000gn/T/ipykernel_1519/2094904254.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2)
#     show_id   type                        title               director  \
# 0       s47  Movie                   Safe House        Daniel Espinosa
# 1       s49  Movie                 Training Day          Antoine Fuqua
# 2       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 3      s123  Movie                   In the Cut           Jane Campion
# 4      s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# ..      ...    ...                          ...                    ...
# 61     s606  Movie              The Long Riders            Walter Hill
# 341   s5168  Movie                     Mudbound               Dee Rees
# 126   s1139  Movie                  The Pianist         Roman Polański
# ...

# %%
df.groupby('country').mean()
# Out:
#                                                     release_year  minus_100
# country
# Argentina                                                2006.00    1906.00
# Australia                                                2010.75    1910.75
# Australia, France                                        2013.00    1913.00
# Australia, United Kingdom, Canada                        2014.00    1914.00
# Australia, United Kingdom, United Arab Emirates...       2015.00    1915.00
# ...                                                          ...        ...
# United States, United Kingdom, France, Germany,...       2013.00    1913.00
# United States, United Kingdom, Germany                   2005.00    1905.00
# United States, United Kingdom, Germany, Hungary          2003.00    1903.00
# United States, United Kingdom, India                     2020.00    1920.00
# United States, United Kingdom, Italy                     2001.00    1901.00
#
# [181 rows x 2 columns]

# %%
df2.groupby('type').count()
# Out:
#        show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie      100    100       100   100      100         100           100
#
#        rating  duration  listed_in  description  minus_100
# type
# Movie     100       100        100          100        100

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>,
#         <AxesSubplot:title={'center':'minus_100'}>]], dtype=object)

# %%
#export data file
#df.to_csv('final_file')
